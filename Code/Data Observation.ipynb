# %% [markdown]
# ## Load Data

# %%
from opencc import OpenCC
import re
import pandas

# %%
from pymongo import MongoClient
client = MongoClient()

# %%
db = client.test
trData = db.sampleset

# %%
import pandas as pd

# %%
trData = trData.find({})
trData = list(trData)
df_trData = pd.DataFrame(trData)
df_trData.head()
# Out:
#                         _id         author  \
# 0  5a826ea13ed17ebe58f25c61          丘份碗66
# 1  5a826ea13ed17ebe58f25c62          asd紫衣
# 2  5a826ea13ed17ebe58f25c63          故事与酒缸
# 3  5a826ea13ed17ebe58f25c64  Caroline_Nine
# 4  5a826ea13ed17ebe58f25c65     qq34314152
#
#                                              content copyrightSource  \
# 0  【昌河汽车将推2款新车】与北汽集团整车事业本部副本部长、江西昌河汽车有限责任公司副总经理廖雄...           丘份碗66
# 1  这天我差点出事哦，我去买烧烤，公交车，我看到个人像鬼，多少路我忘记了，后来跟着个杨洋的什么广...           asd紫衣
# 2  【广菲克产销分离JEEP国产在即】在4月20日举办的上海国际车展上，广菲克展出了包括菲翔米兰...           故事与酒缸
# 3  消防车🚒//@APP菌:哈哈哈哈哈哈哈哈谈个恋爱还不够生气的//@一个阿呆仔:学猪叫那个真笑...   Caroline_Nine
# 4  【微电影|无处可逃】2017年10月31日上午，[xkl达达黑暗]杨辰和孙彬两位小伙子相约到...      qq34314152
#
#                      id          last_update pubSource     pubTime  \
# 0  -9223352888553609071  2018-01-29 22:48:53      新浪微博  1517050815
# 1  -9223363810167202147  2018-01-15 09:29:57      新浪微博  1515967706
# 2  -9223357131622972986  2018-01-11 01:31:56      新浪微博  1515597336
# 3  -9223330358968196918  2018-01-20 16:36:19      新浪微博  1516422278
# 4  -9223311817460417728  2018-01-21 07:46:52      新浪微博  1516469637
#
#            title                                    url
# 0          丘份碗66  http://weibo.com/6142925293/G0mQ3azgA
# 1          asd紫衣  http://weibo.com/6276804601/FEq78giV6
# 2          故事与酒缸  http://weibo.com/5759812287/FDLHA0DtI
# 3  Caroline_Nine  http://weibo.com/1875936727/FFdIjvCCL
# 4     qq34314152  http://weibo.com/2387005072/FFiSHoepC

# %%
df_trData.tail()
# Out:
#                              _id      author  \
# 561023  5a826eb03ed17ebe58faee17          遁之
# 561024  5a826eb03ed17ebe58faee18    刘晨宇53015
# 561025  5a826eb03ed17ebe58faee19  想要超级活跃的木可呀
# 561026  5a826eb03ed17ebe58faee1a    临汾市地方税务局
# 561027  5a826eb03ed17ebe58faee1b     裴裴Avril
#
#                                                   content copyrightSource  \
# 561023  下午看完电影去万达等基友考完六级约饭 [跪了]基友看到我说我今天画个妆跟被打了一样。。。手残...              遁之
# 561024  这两天的扬州，一定很冷，我报考了一个车票，特别没信心，可是我一想到你，我就必须努力，不能放松...        刘晨宇53015
# 561025  想转遍微博所有的锦鲤 保佑我以后不会错过末班车 保佑我以后可以很快等到想等的车 好吗老天爷 ...      想要超级活跃的木可呀
# 561026  #政策解读#关于《国家税务总局关于水资源费改税后城镇公共供水企业增值税发票开具问题的公告》的...        临汾市地方税务局
# 561027  四点就让俩男的回家了，[哆啦A梦花心][哆啦A梦花心][哆啦A梦花心]跟姐姐俩人走路从原宿逛...         裴裴Avril
#
#                          id          last_update pubSource     pubTime  \
# 561023  9223204564867568375  2018-01-03 14:51:34      新浪微博  1514945701
# 561024  9223231308036706708  2018-01-30 05:19:57      新浪微博  1517160914
# 561025  9223359805106915076  2018-01-21 03:26:04      新浪微博  1516465791
# 561026  9223330813878104334  2017-12-29 18:31:33      新浪微博  1514533121
# 561027  9223192223359380255  2018-01-21 08:10:42      新浪微博  1516484694
#
#              title                                    url
# 561023          遁之  http://weibo.com/3170112043/FCCBfFWxw
# 561024    刘晨宇53015  http://weibo.com/5479542550/G0yQRss5S
# 561025  想要超级活跃的木可呀  http://weibo.com/6042158665/FFisGhtsV
# 561026    临汾市地方税务局  http://weibo.com/6424562753/FBTA9zI95
# 561027     裴裴Avril  http://weibo.com/3903203249/FFkwyi484

# %%
df_trData['last_update'][1000:3000]
# Out:
# 1000    2018-01-23 13:01:57
# 1001    2018-01-25 01:54:09
# 1002    2018-01-30 04:38:40
# 1003    2017-12-21 17:50:37
# 1004    2018-01-24 13:02:36
# 1005    2018-01-22 21:02:50
# 1006    2018-01-23 14:37:53
# 1007    2018-01-30 05:14:00
# 1008    2018-01-24 18:52:37
# 1009    2018-01-14 01:00:22
# 1010    2018-01-06 18:57:25
# 1011    2017-12-21 17:50:37
# 1012    2018-01-14 23:38:39
# 1013    2018-01-12 08:43:21
# 1014    2018-01-30 02:16:00
# 1015    2017-12-26 20:06:53
# 1016    2018-01-24 03:35:35
# 1017    2018-01-26 22:29:35
# 1018    2018-01-06 14:54:00
# 1019    2018-01-08 23:48:40
# 1020    2018-01-26 15:42:26
# 1021    2018-01-19 20:54:49
# 1022    2018-01-22 04:07:32
# 1023    2018-01-20 22:22:56
# 1024    2018-01-24 19:46:06
# 1025    2018-01-13 07:32:12
# 1026    2018-01-19 22:26:43
# 1027    2018-01-26 04:28:16
# 1028    2018-01-01 01:45:39
# 1029    2018-01-24 08:07:59
#                ...
# 2970    2018-01-13 20:10:46
# 2971    2017-12-27 18:25:02
# 2972    2018-01-20 03:32:08
# 2973    2018-01-02 16:01:54
# 2974    2017-12-21 17:50:37
# 2975    2018-01-08 17:11:46
# 2976    2018-01-20 16:47:07
# 2977    2018-01-24 19:10:21
# 2978    2018-01-21 07:59:27
# 2979    2017-12-24 04:42:41
# 2980    2018-01-26 21:34:51
# 2981    2017-12-21 17:50:37
# 2982    2018-01-30 05:22:37
# 2983    2018-01-06 05:57:28
# 2984    2017-12-21 17:50:37
# 2985    2018-01-25 02:31:39
# 2986    2017-12-21 17:50:37
# 2987    2018-01-19 12:41:47
# 2988    2018-01-25 07:05:51
# 2989    2018-01-29 22:34:54
# 2990    2018-01-21 02:58:33
# 2991    2018-01-21 13:03:28
# 2992    2018-01-01 14:38:10
# 2993    2018-01-23 14:30:21
# 2994    2017-12-21 17:50:37
# 2995    2018-01-12 17:21:57
# 2996    2017-12-21 17:50:37
# 2997    2018-01-20 22:20:48
# 2998    2018-01-18 20:56:17
# 2999    2018-01-10 02:52:06
# Name: last_update, Length: 2000, dtype: object

# %%
df_trData = df_trData[~df_trData['content'].isnull()]

# %%
df_content = df_trData[['content']]

# %%
df_content[0:100]
# Out:
#                                               content
# 0   【昌河汽车将推2款新车】与北汽集团整车事业本部副本部长、江西昌河汽车有限责任公司副总经理廖雄...
# 1   这天我差点出事哦，我去买烧烤，公交车，我看到个人像鬼，多少路我忘记了，后来跟着个杨洋的什么广...
# 2   【广菲克产销分离JEEP国产在即】在4月20日举办的上海国际车展上，广菲克展出了包括菲翔米兰...
# 3   消防车🚒//@APP菌:哈哈哈哈哈哈哈哈谈个恋爱还不够生气的//@一个阿呆仔:学猪叫那个真笑...
# 4   【微电影|无处可逃】2017年10月31日上午，[xkl达达黑暗]杨辰和孙彬两位小伙子相约到...
# 5   【Bee Dragon打造完美VIP丰田皇冠】Bee Dragon打造的标志性VIP风格。B...
# 6   #我有红唇给我红包#【MINI PACEMAN 皮卡】MINI发布了PACEMAN Adve...
# 7   人社部财政部近日联合印发了《企业年金办法》，自2018年2月1日起施行。 企业缴费每年不超过...
# 8   【科鲁兹两厢版】外观设计上，科鲁兹两厢版除了尾部设计外均与三厢版一致。全新的家族式分体格栅以...
# 9   生日蛋糕目前还是延续先前的活动哦 有过交易记录的老顾客预订生日蛋糕可享立减50元优惠 新顾客...
# 10  2017.4.22-4.28 蔚来速递第7期 | 上海车展每10辆展车就有1辆新能源车 ht...
# 11  1月19日早报，星期五，农历腊月初三 1、富可敌国！深圳GDP总量已超以色列、南非、新加坡、...
# 12  【众泰M300仪表模块存安全隐患】M300是众泰汽车推出的一款拥有大空间的多功能MPV车型，...
# 13  #台湾小记-动物园旁的空地#对台湾的印象是绿化很好。绿地占有面积公共社区配套什么的都做得很好...
# 14        哈哈//@中国工商银行:王老师辛苦了，刚下节目就发微博。新年快乐。#和工行一起云跨年#
# 15  下雪的冬夜温暖的人！回家必经过一座桥，在锰都会车的时候，一辆标致慢吞吞开过来，我以为他过不去...
# 16  【汽车界新闻——或推多款衍生车型新奔驰A级效果图曝光】国外媒体曝出了一组新奔驰A级车的最新效...
# 17  涨乐财富通跨年狂欢季——为华泰证券资管打call，投票还有乐米拿！ http://t.cn/...
# 18  #法治微课堂# 【曝光！女司机酒驾撞俩车后逃逸被挡，叫嚣：我有关系！[怒]】近日，成都一名女...
# 19  【恒丰银行董事长蔡国华涉嫌严重违纪，正在接受调查！】11月28日，澎湃新闻从恒丰银行专题会议...
# 20  #琅琊榜之风起长林#【新款别克君威上市 售17.89-29.99万元】近日获悉，2015款君...
# 21  记得早先少年时 大家诚诚恳恳 说一句 是一句 清早上火车站 长街黑暗无行人 卖豆浆的小店冒着...
# 22  DAY 31 2018年1月17日 学习内容：税法9、10讲 学习时间：2.5小时 问：买“...
# 23  涨乐财富通跨年狂欢季——为华泰证券资管打call，投票还有乐米拿！http://t.cn/R...
# 24  Arya真可爱 紫薯真甜呢 可是今年集美万达的圣诞树真的丑 http://t.cn/z8AJVYM
# 25  【恒指午盘大涨1.18%再创新高 内银股全线走强】香港恒生指数午盘涨1.18%，报32775...
# 26           越野酷炫汽车总动员 消防车赛车 创意游戏 http://t.cn/RQLQNj5
# 27  老孙增资，实际上是收了众多小股东的股权，股权集中，为万达电影并入做准备。//@ifwl:第一...
# 28  //@Cars01:三里屯门口的代驾：西方哪个品牌的车我没开过？哪个外国车我不知道钥匙往哪插...
# 29  别人的考完最后一科，朝阳约吗万达去吗逛吃逛买，我的呢马不停蹄上夜班，简单粗暴都不用选择。[d...
# ..                                                ...
# 70  乐视网停牌9个月了，贾跃亭也走了，乐视网的朋友也早在危机之前跳到了万达信息， 看近期的公告，...
# 71  今天和我妈去街对面的小火锅店吃饭 吃完回来过长城花园门前的十字路口 斑马线两旁还闪着黄色信号...
# 72  在日益倡导环保的今天，混合动力的车也越来越普及。这款混合动力的电动车由一家以研发新能源为主的...
# 73  宁波鄞州万达车展，1月6号到14号要兼职9人，8女1男，早九晚十(正式一般十点开始），连做。...
# 74  受益于低利率和通货膨胀的影响！不过伴随着东盟计划2018年取消该地区各成员国间的进口关税：越...
# 75  低学历宝妈---CICI 92年，25岁 在从事微商之前在外打工4年，初中学历，换过无数的工...
# 76  下午看完电影去万达等基友考完六级约饭 [跪了]基友看到我说我今天画个妆跟被打了一样。。。手残...
# 77  【戴姆勒84万辆车存伤亡隐患在美召回】本次召回范围内的部分车辆由于供应商制造问题，驾驶员及副...
# 78                                   从财政部宝宝宝宝宝宝宝宝宝宝宝宝
# 79  12分钟急送病人！吉林交警开辟雨中“绿色通道” 4月24日，[阴险][阴险][阴险]#大雪冬...
# 80  浪漫是一袭美丽的晚礼服，但你不能一天到晚都穿着它啊。我们发现您刚刚发生了一笔境外网站消费、这...
# 81  用了这么久平安银行都还不知道这些福利？ 用了这么久平安银行都还不知道这些福利？ http:/...
# 82  中国人民银行今日早间发布消息表示，目前银行体系流动性总量较高，可吸收央行逆回购到期等因素的影...
# 83        @万达百货 @万达集团 @王思聪 余生请多指教 http://t.cn/RJLJBbU
# 84  阳奉阴违 美国财政部上月公布的卫星图片显示，在黄海附近的公海上，中国和朝鲜的船只连接在一起，...
# 85  #林峯#[音乐]#林峯大泼猴# 171231南昌万达乐园抖音跨年夜 林峯（爱在记忆中找你）（...
# 86  【今天央行发行3元10元硬币 快看看长啥样？】中国人民银行决定：自2017年12月15日起，...
# 87  【警惕“刺眼”威胁 迎着阳光驾车需注意】使用遮阳板；佩戴太阳镜；挡风玻璃处不要放置车证等反光...
# 88  即便窗前的绿地，也只是青色略略枯黄了草头。以及生活在成都里形形色色的佳人，那一个皮肤白皙、五...
# 89                     帽子虐，灯光虐，万达场全糊#英雄本色2018##王凯kkw#
# 90  在瓜子二手车卖场过程。月初，下午瓜子二手车来做登记以及上传官网，下午四点左右又一个工作人过来...
# 91  申请了一个王俊凯的信用卡[笑cry][笑cry][笑cry][笑cry]希望工商银行让我通过...
# 92  中国农业银行2018年校园及大学生村官招聘体检通知(同步自@新浪看点)http://t.cn...
# 93                               是谁说万达楼上的阿香米线好吃 我磨刀等你
# 94  #平安守护# H 冬季应当如何正确热车呢? 很多人知道要热车，但并不知道为什么要热车。其实，...
# 95                     #再见1月# 航拍绿地大厦，再见1月，一年之约，还剩11个月
# 96                哈哈哈哈哈你真的好爱抽奖哦[爱你][爱你]@中国工商银行 @公子苏小艾
# 97  每天夜里，饿的火冒金星，幸好嘴下留情，我正在做思想斗争要不要现在爬起来，还是起来吧，饥饿感和...
# 98  //@嫦娥姐姐收玉兔精:🙈[好喜欢]浦发代言人张艺兴大发，浦发银行大发 #张艺兴# #张艺兴...
# 99  #媒体看中行#【中国银行浙江舟山普陀山支行蝉联“全国文明单位”五连冠[人民网浙江频道]】20...
#
# [100 rows x 1 columns]

# %%
sent_pattern = u"[\u0030-\u0039\u4e00-\u9fa5\u3040-\u309f\u30a0-\u30ff\u2000-\u2025\u2027\u206f\u3000-\u3001\u3003-\u3009\u3012-\u303f\uff00\uff02-\uff1f\uff20-\uffef]+[\u3002|\uff1f|\uff01|\u3010|\u3011|\u2026]+"
tag_pattern = u"\u0023+[\u0020-\u007f\u4e00-\u9fa5\u3040-\u309f\u30a0-\u30ff]+?\u0023"
id_pattern = u"\u0040+[\u0020-\u007f\u4e00-\u9fa5\u3040-\u309f\u30a0-\u30ff]+?\u003A"
url_pattern = "http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+"
mail_pattern = "^\\s*\\w+(?:\\.{0,1}[\\w-]+)*@[a-zA-Z0-9]+(?:[-.][a-zA-Z0-9]+)*\\.[a-zA-Z]+\\s*$"

# %%
pa = tag_pattern+'|'+id_pattern+'|'+url_pattern+'|'+mail_pattern

# %%
def get_tag(txt):
    #繁簡體
    #大小寫
    #空格合併
    newtxt = ' '.join(txt.split())
    #暫時忽略tag
    newtxt = re.sub(pa, '', newtxt)
    #忽略博主名
    #newtxt = re.sub(id_pattern, '', newtxt)
    #忽略網址
    #newtxt = re.sub(url_pattern, '', newtxt)
    #忽略郵箱
    #newtxt = re.sub(mail_pattern, '', newtxt)
    return newtxt
    #print(re.findall(tag_pattern,row['content'])

# %%
df_content['content1'] = df_content.apply(lambda row: get_tag(row['content']), axis = 1)
# Out:
# /Users/sophia.gao/.pyenv/versions/miniconda2-latest/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_content[10:20]
# Out:
#                                               content  \
# 10  2017.4.22-4.28 蔚来速递第7期 | 上海车展每10辆展车就有1辆新能源车 ht...
# 11  1月19日早报，星期五，农历腊月初三 1、富可敌国！深圳GDP总量已超以色列、南非、新加坡、...
# 12  【众泰M300仪表模块存安全隐患】M300是众泰汽车推出的一款拥有大空间的多功能MPV车型，...
# 13  #台湾小记-动物园旁的空地#对台湾的印象是绿化很好。绿地占有面积公共社区配套什么的都做得很好...
# 14        哈哈//@中国工商银行:王老师辛苦了，刚下节目就发微博。新年快乐。#和工行一起云跨年#
# 15  下雪的冬夜温暖的人！回家必经过一座桥，在锰都会车的时候，一辆标致慢吞吞开过来，我以为他过不去...
# 16  【汽车界新闻——或推多款衍生车型新奔驰A级效果图曝光】国外媒体曝出了一组新奔驰A级车的最新效...
# 17  涨乐财富通跨年狂欢季——为华泰证券资管打call，投票还有乐米拿！ http://t.cn/...
# 18  #法治微课堂# 【曝光！女司机酒驾撞俩车后逃逸被挡，叫嚣：我有关系！[怒]】近日，成都一名女...
# 19  【恒丰银行董事长蔡国华涉嫌严重违纪，正在接受调查！】11月28日，澎湃新闻从恒丰银行专题会议...
#
#                                              content1
# 10  2017.4.22-4.28 蔚来速递第7期 | 上海车展每10辆展车就有1辆新能源车 ht...
# 11  1月19日早报，星期五，农历腊月初三 1、富可敌国！深圳GDP总量已超以色列、南非、新加坡、...
# 12  【众泰M300仪表模块存安全隐患】M300是众泰汽车推出的一款拥有大空间的多功能MPV车型，...
# 13  对台湾的印象是绿化很好。绿地占有面积公共社区配套什么的都做得很好。至少公共栖息地（不知道有没...
# 14                          哈哈//王老师辛苦了，刚下节目就发微博。新年快乐。
# 15  下雪的冬夜温暖的人！回家必经过一座桥，在锰都会车的时候，一辆标致慢吞吞开过来，我以为他过不去...
# 16  【汽车界新闻——或推多款衍生车型新奔驰A级效果图曝光】国外媒体曝出了一组新奔驰A级车的最新效...
# 17  涨乐财富通跨年狂欢季——为华泰证券资管打call，投票还有乐米拿！ http://t.cn/...
# 18   【曝光！女司机酒驾撞俩车后逃逸被挡，叫嚣：我有关系！[怒]】近日，成都一名女司机付某喝近1...
# 19  【恒丰银行董事长蔡国华涉嫌严重违纪，正在接受调查！】11月28日，澎湃新闻从恒丰银行专题会议...

# %%
def strQ2B(ustring):
    """把字符串全角转半角"""
    rstring = ""
    for uchar in ustring:
        inside_code=ord(uchar)
        # 全角字符unicode编码从65281~65374 （十六进制 0xFF01 ~ 0xFF5E）
        # 半角字符unicode编码从33~126 （十六进制 0x21~ 0x7E）
        # 而且除空格外,全角/半角按unicode编码排序在顺序上是对应的
        if inside_code==0x3000:
            # 空格 全角为0x3000 半角为0x0020
            inside_code=0x0020
        elif inside_code == 0x3002:
            # 中文句号
            inside_code=0x2e
        else:
            inside_code-=0xfee0
        if inside_code<0x0020 or inside_code>0x7e:      
            rstring += uchar
        else:
            rstring += chr(inside_code)
    return rstring

# %%
df_content['content1'] = df_content.apply(lambda row: strQ2B(row['content1']), axis = 1)
# Out:
# /Users/sophia.gao/.pyenv/versions/miniconda2-latest/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## Merge to One String

# %%
import re

# %%
len(df_list)
# Out:
# 561028

# %%
df_list = df_content['content'].tolist()

# %%
df_all_in_one = ' '.join(df_list)
df_all_in_one = ' '.join(df_all_in_one.split())

# %%
openCC = OpenCC('t2s')
txt = openCC.convert(txt).lower()

# %%
handle = re.sub(pa,'',df_all_in_one)

# %%
split_row = re.split('。+|！+|？+|…+|/+|】|：|【', handle)

# %%
import pandas

# %%
tmp = pandas.DataFrame(split_row)

# %%
tmp.head()
# Out:
#                                              0
# 0
# 1                                   昌河汽车将推2款新车
# 2     与北汽集团整车事业本部副本部长、江西昌河汽车有限责任公司副总经理廖雄辉沟通后获悉
# 3
# 4  昌河汽车在上海车展发布了全新福瑞达M50S并公布了首款SUV车型，两款车都将于年内上市

# %%
tmp.count()
# Out:
# 0    2111970
# dtype: int64

# %%
tmp = tmp.rename({0: "sent"}, axis='columns')

# %%
tmp = tmp[tmp['sent'].apply(lambda row:len(row)>=2)]

# %%
tmp.to_csv('tmp.csv', sep='\t', encoding='utf-8')

# %% [markdown]
# ## TEST: Text Filtering

# %% [markdown]
# * http: or https:
# * 【】subtitle
# * #tag# @person_
# * emoji

# %%
import re

# %%
zh_char = u"[\u4e00-\u9fa5\u3040-\u309f\u30a0-\u30ff]+"
zh_punc = u"[\u2000-\u206f\u3000-\u303f\uff00-\uffef]+"
zh_patt = u"[\u0030-\u0039\u4e00-\u9fa5\u2000-\u206f\u3000-\u303f\u3040-\u309f\u30a0-\u30ff\uff00-\uffef]+"
zh_half_punc = u"[\u2000-\u2025\u2027\u206f\u3000-\u3001\u3003-\u3009\u3012-\u303f\uff00\uff02-\uff1f\uff20-\uffef]+"
en_char = u"[\u0020-\u007f]+"
sent_pattern = u"[\u0030-\u0039\u4e00-\u9fa5\u3040-\u309f\u30a0-\u30ff\u2000-\u2025\u2027\u206f\u3000-\u3001\u3003-\u3009\u3012-\u303f\uff00\uff02-\uff1f\uff20-\uffef]+[\u3002|\uff1f|\uff01|\u3010|\u3011|\u2026]+"

# %%
df_all_in_one[0:500]
# Out:
# '【昌河汽车将推2款新车】与北汽集团整车事业本部副本部长、江西昌河汽车有限责任公司副总经理廖雄辉沟通后获悉：“昌河汽车在上海车展发布了全新福瑞达M50S并公布了首款SUV车型，两款车都将于年内上市。“ 这天我差点出事哦，我去买烧烤，公交车，我看到个人像鬼，多少路我忘记了，后来跟着个杨洋的什么广告，我心定了//@张若昀: 一杯不会止一杯 【广菲克产销分离JEEP国产在即】在4月20日举办的上海国际车展上，广菲克展出了包括菲翔米兰典藏版、致悦Cross概念车、致悦Mefisto概念车、菲翔跃享版、致悦豪华运动版和菲亚特500等在内的8款车型。而这也是广菲克销售公司挂牌前，在“家门口”的第一次联合演出。 消防车🚒//@APP菌:哈哈哈哈哈哈哈哈谈个恋爱还不够生气的//@一个阿呆仔:学猪叫那个真笑出猪声[允悲]//@梨园西池水: 哈哈哈哈哈哈哈哈哈哈//@太皇太后您有喜啦:哈哈哈哈哈哈哈哈哈怎么这么好笑ˊ_>ˋ 【微电影|无处可逃】2017年10月31日上午，[xkl达达黑暗]杨辰和孙彬两位小伙子相约到盐城市城市商业中心——万达广场游玩，他们在大门口等待商场开门时…… [47]【动画电影集散地原'

# %%
re.split('。|！|？|…|//|： ',df_all_in_one[0:5000])
# Out:
# ['【昌河汽车将推2款新车】与北汽集团整车事业本部副本部长、江西昌河汽车有限责任公司副总经理廖雄辉沟通后获悉：“昌河汽车在上海车展发布了全新福瑞达M50S并公布了首款SUV车型，两款车都将于年内上市',
#  '“ 这天我差点出事哦，我去买烧烤，公交车，我看到个人像鬼，多少路我忘记了，后来跟着个杨洋的什么广告，我心定了',
#  '@张若昀: 一杯不会止一杯 【广菲克产销分离JEEP国产在即】在4月20日举办的上海国际车展上，广菲克展出了包括菲翔米兰典藏版、致悦Cross概念车、致悦Mefisto概念车、菲翔跃享版、致悦豪华运动版和菲亚特500等在内的8款车型',
#  '而这也是广菲克销售公司挂牌前，在“家门口”的第一次联合演出',
#  ' 消防车🚒',
#  '@APP菌:哈哈哈哈哈哈哈哈谈个恋爱还不够生气的',
#  '@一个阿呆仔:学猪叫那个真笑出猪声[允悲]',
#  '@梨园西池水: 哈哈哈哈哈哈哈哈哈哈',
#  '@太皇太后您有喜啦:哈哈哈哈哈哈哈哈哈怎么这么好笑ˊ_>ˋ 【微电影|无处可逃】2017年10月31日上午，[xkl达达黑暗]杨辰和孙彬两位小伙子相约到盐城市城市商业中心——万达广场游玩，他们在大门口等待商场开门时',
#  '',
#  ' [47]【动画电影集散地原创】の《The Polar Express》〔20050121〕某天我们突然对自己曾经 【Bee Dragon打造完美VIP丰田皇冠】Bee Dragon打造的标志性VIP风格',
#  'Bee Dragon 定制前保险杠，前大灯调色搭配HID 雾灯，霸气的前脸，不怒自威',
#  'VIP改装车的效果总是令人惊叹',
#  '专业定制的气动悬挂，趴地下是必须的',
#  '外倾角并没有夸张到接受不了，这么一辆车停在路边，没有谁不会去多看两眼把',
#  ' #我有红唇给我红包#【MINI PACEMAN 皮卡】MINI发布了PACEMAN Adventure Concept概念车的官方图片',
#  '这款车仅会生产一台，目前MINI并没有计划将其量产',
#  'PACEMAN Adventure Concept概念车是基于PACEMAN普通版车型改进而来的一款皮卡车型，该车采用绿色涂装，车顶配有探照灯以及置物架',
#  ' 人社部财政部近日联合印发了《企业年金办法》，自2018年2月1日起施行',
#  ' 企业缴费每年不超过工资总额的8%，企业和职工个人缴费合计不超过12%',
#  '具体由企业和职工协商确定',
#  '企业年金基金实行完全积累，为每个职工建立个人账户，按照国家有关规定投资运营；收益并入企业年金基金 http:',
#  't.cn/RH4ub6c 【科鲁兹两厢版】外观设计上，科鲁兹两厢版除了尾部设计外均与三厢版一致',
#  '全新的家族式分体格栅以及带有U型LED日间行车灯的前大灯组，配合保险杠、翼子板以及车侧的折线设计，营造出了犀利的车身线条',
#  ' 生日蛋糕目前还是延续先前的活动哦 有过交易记录的老顾客预订生日蛋糕可享立减50元优惠 新顾客预订可减20元 限预订8寸以上生日蛋糕，每人限定一个，不可与其它活动同享，如需外送的，外送费按实际地址收取，武汉的亲可以来菱角湖万达这边自提 活动只接到2.13. 2017.4.22-4.28 蔚来速递第7期 | 上海车展每10辆展车就有1辆新能源车 http:',
#  't.cn/RQdB5bV 1月19日早报，星期五，农历腊月初三 1、富可敌国',
#  '深圳GDP总量已超以色列、南非、新加坡、丹麦等160多个国家',
#  '足足相当于14个冰岛',
#  ' 2、重磅',
#  '我国GDP总量首登80万亿门槛，GDP同比增长6.9%，七年来首提速，收入增速跑赢GDP； 3、国家统计局：2017年全国男性比女性多3266万人； 4、保监会、财政部正式... http:',
#  'm.weibo.cn/client/version 【众泰M300仪表模块存安全隐患】M300是众泰汽车推出的一款拥有大空间的多功能MPV车型，好好的记下那些该记住的日子吧；因M300仪表模块存在安全隐患，众泰汽车将召回部分M300车型',
#  ' #台湾小记-动物园旁的空地#对台湾的印象是绿化很好',
#  '绿地占有面积公共社区配套什么的都做得很好',
#  '至少公共栖息地（不知道有没有这说法）小鸟还不怕人',
#  '感觉印象是香港和澳门的合体',
#  '没有香港的快然而融合了一点澳门的小街特色',
#  '街道干净整洁',
#  '不过最大问题就是没有垃圾桶',
#  '',
#  '',
#  '真的找不到垃圾桶',
#  '之前 ... http:',
#  'm.weibo.cn/client/version 哈哈',
#  '@中国工商银行:王老师辛苦了，刚下节目就发微博',
#  '新年快乐',
#  '#和工行一起云跨年# 下雪的冬夜温暖的人',
#  '回家必经过一座桥，在锰都会车的时候，一辆标致慢吞吞开过来，我以为他过不去，有往里面让了让',
#  '谁知标志打开了双闪，摇下了车窗，对我喊道：“前面桥上结冰了',
#  '刹不住车',
#  '慢慢开',
#  '刹不住车',
#  '已经有车撞了',
#  '”我急忙说谢谢',
#  '然后以龟速通过了桥',
#  '桥面一层薄冰，两辆撞得面目全非的... http:',
#  'm.weibo.cn/client/version 【汽车界新闻——或推多款衍生车型新奔驰A级效果图曝光】国外媒体曝出了一组新奔驰A级车的最新效果图，三菱汽车总经理DonSwearingen向媒体透露；另据国内媒体报道',
#  '',
#  ' 涨乐财富通跨年狂欢季——为华泰证券资管打call，投票还有乐米拿',
#  ' http:',
#  't.cn/RH9tOA2 #法治微课堂# 【曝光',
#  '女司机酒驾撞俩车后逃逸被挡，叫嚣：我有关系',
#  '[怒]】近日，成都一名女司机付某喝近1斤白酒后驾车，连撞两辆车逃逸，随后被警方挡获',
#  '付某大闹警队：我有关系，你们凭什么关我',
#  '”蜀黍在此正告：法律面前人人平等',
#  'http:',
#  't.cn/RQdyhwe 【恒丰银行董事长蔡国华涉嫌严重违纪，正在接受调查',
#  '】11月28日，澎湃新闻从恒丰银行专题会议上获悉，恒丰银行董事长蔡国华涉嫌严重违纪违法，正接受调查',
#  '阳信人',
#  ' #琅琊榜之风起长林#【新款别克君威上市 售17.89-29.99万元】近日获悉，2015款君威已经正式上市，新车共推出2.0L、1.6T、2.0T三种动力的共8款车型',
#  '作为年度改款车型，新车的外观造型基本不会发生变化，但内饰配色上为2.0T GS 豪情运动版、2.0T GS 燃情运动版以及1.6T精英技术型三款车增加了Alcantara太... http:',
#  'm.weibo.cn/client/version 记得早先少年时 大家诚诚恳恳 说一句 是一句 清早上火车站 长街黑暗无行人 卖豆浆的小店冒着热气 从前的日色变得慢 车，马，邮件都慢 一生只够爱一个人 从前的锁也好看 钥匙精美有样子 你锁了 人家就懂了 ——木心《从前慢》 http:',
#  't.cn/RN4t9vs DAY 31 2018年1月17日 学习内容：税法9、10讲 学习时间：2.5小时 问：买“房”还是买“车”',
#  ' 答：我买“白起”',
#  ' #CPA打卡# 涨乐财富通跨年狂欢季——为华泰证券资管打call，投票还有乐米拿',
#  'http:',
#  't.cn/RHqTjHR Arya真可爱 紫薯真甜呢 可是今年集美万达的圣诞树真的丑 http:',
#  't.cn/z8AJVYM 【恒指午盘大涨1.18%再创新高 内银股全线走强】香港恒生指数午盘涨1.18%，报32775.88点，恒生国企指数涨1.63%，恒生红筹指数涨0.28%，半日大市成交1064.6亿港元',
#  '吉利汽车大涨8.91%，领涨蓝筹，建设银行涨3.1%，中国银行涨2.95%，工商银行、银河娱乐涨近2%，腾讯控股涨1.74%，中国平安、中国人寿、友邦... http:',
#  'm.weibo.cn/client/version 越野酷炫汽车总动员 消防车赛车 创意游戏 http:',
#  't.cn/RQLQNj5 老孙增资，实际上是收了众多小股东的股权，股权集中，为万达电影并入做准备',
#  '',
#  '@ifwl:第一步FF融资到位，第二步乐视影业股权理顺，第三步万达入住乐视，各位看倌觉得如何😄? ',
#  '@Cars01:三里屯门口的代驾：西方哪个品牌的车我没开过',
#  '哪个外国车我不知道钥匙往哪插',
#  '意大利的法拉利488知道吗',
#  '670匹，比五菱不知道高到哪里去了，我操控自如，一直保持在30迈，你们啊，还是要提高自己的驾驶水平[doge] #cars01车闻# 别人的考完最后一科，朝阳约吗万达去吗逛吃逛买，我的呢马不停蹄上夜班，简单粗暴都不用选择',
#  '[doge] 南昌万达乐园跨年#戴佩妮# ❤️野蔷薇 怎样 你要的爱 祝阿妮和猴子们新年快乐🎉 http:',
#  't.cn/RHNYTun #让红包飞# 新年吉祥2018 【教练怂恿学院酒后驾车上高速：[怒]他开得好没关系 [摊手]】10月17日，湖南郴州，一辆教练车在高速上“左摇右晃”，交警检查时发现，司机竟然是没有驾照的学员，教练也在车里，两人都喝了酒',
#  '酒驾监测时，教练说：“怎么处罚就怎么处罚怕什么，违法就违法',
#  '” ... http:',
#  'm.weibo.cn/client/version 信用卡是多军必备防身武器，老司机可防身，新手跳过原始积累 很多人理解的信用卡就是用来逛逛商场，加加油，撸撸机票的作用，其实“别有洞天” 为什么信用卡背后有百万财富',
#  ' 因为：招商备用金30万 因为：浦发万用金30万 因为：广发财智金30万 因为：交通好享贷30万 因为：兴业兴灵30万 因为：中信新快线+圆梦金50 万 因为：光大乐惠金30万 因为：平安灵用金30万 因为：民生通宝卡30万 因为：华夏易达金30万 因为：工行新融借30万 因为：建行快贷放30 万 因为：中行E贷新30万 因为：农行网捷30 万 因为：中邮邮享贷30万 因为：北京通信贷12万 这些都是一张普普通通的信用卡可以用出来的；刷出来的贷款',
#  ' ️同时还有 支付宝：蚂蚁借呗30万 微信：微粒贷30 万 万达贷30万 招联金融30 万 京东金条30 万 网商法人贷100万 在我眼中，您拥有500万',
#  ' 我们算算每个有信用的人背后的信用财富',
#  '⒈ 十五家银行15张信用卡，每张信用卡5 万额度，约计75 万',
#  ' ⒉ 15 张信用卡背后贷款各30 万，约计450 万',
#  ' 让我们养成良好用卡习惯，保护好个人信用，激活500万信用财富',
#  ' 请扫码加入知识星球，让你用额度变成深圳的房子 #周口新鲜事# 【神操作：化妆镜竟被当做后视镜】1月12日，河南沈丘，拍客发现一车左后视镜是化妆镜',
#  '司机说后视镜被撞碎， 4S店不能马上维修，所以自己先“修”了上路，还邀请拍客上车体验',
#  ' http:',
#  't.cn/RQU0VBk 2017独自一人一共看了21部电影：最爱去的电影院是sm万达影城；最常看的电影类型是科幻动作；最喜欢的观影时间是17:00',
#  ' 万达很有可能入股影业，乐视志新很有可能就孙宏斌自己干了， 【申花抵达马贝拉展开集训】北京时间今天，上海绿地申花队在经过了飞机、高铁加大巴的漫长旅途后抵达了此次海外集训目的地—西班牙马贝拉，正式开启为期一个月的冬训拉练',
#  '全队在抵达马贝拉后进行了简单的用餐和休息，短短两个小时后就出现在训练场进行了首堂训练课',
#  ' 皇台酒业（000995）：签订1.48亿元文化酒供货合同 北京银行：董事会同意聘任杨书剑为行长 停复牌>>> 停牌：*ST众和、大康农业（002505） 复牌：银之杰（300085）、共达电声（002655）、睿康股份（002692）、闻泰科技（600745） 月付 中粮方圆府 东兴府 西文西苑 精装修 无中介费 精装修，家具配套齐全，周边有西文公园，中大银泰城，物美超市，金逸影视城，新天地，工商银行，联合银行，西文农贸市场等等配套设施齐全，吃饭，购物，休闲娱乐非常方便，出门走几步就公交站，电梯房，需要联系，不收中介费 ， 1400起，合租 该单... http:',
#  'm.weibo.cn/client/version #我有红唇给我红包#【东风标致将产7款新车 含首款“电动”车】对于未来产品规划，神龙汽车有限公司总经理邱现东先生表示：“东风标致将保持每年至少一款新车型投放市场，2016-2020年共计将推出7款战略车型',
#  '”7款新车中，将包括旗舰轿车、高端SUV以及采用新能源技术的插电混动车',
#  ' 可可今天我在万达广场主持了一下午儿童娱乐节目都是5-6岁的小朋友上台表演跳舞玩玩具等，同时音响师放了一下午你的那首萌萌哒歌曲，']

# %%
from nltk.tokenize import TweetTokenizer 
tw = TweetTokenizer()
#tw.tokenize(df_all_in_one[5000:6000])

# %%
pa = u"\u0023+[\u4e00-\u9fa5\u3040-\u309f\u30a0-\u30ff]+\u0023"

# %%
b = re.findall(pa,df_all_in_one)

# %%
b
# Out:
# ['#我有红唇给我红包#',
#  '#和工行一起云跨年#',
#  '#法治微课堂#',
#  '#琅琊榜之风起长林#',
#  '#戴佩妮#',
#  '#让红包飞#',
#  '#周口新鲜事#',
#  '#我有红唇给我红包#',
#  '#中国人寿#',
#  '#平安守护#',
#  '#快乐冰雪季#',
#  '#陈伟霆#',
#  '#轻松一刻#',
#  '#公司研报#',
#  '#属于我的金球时刻#',
#  '#林峯#',
#  '#林峯大泼猴#',
#  '#平安守护#',
#  '#张艺兴#',
#  '#张艺兴代言浦发信用卡#',
#  '#张艺兴梦想起飞#',
#  '#张艺兴湖南卫视跨年#',
#  '#张艺兴偶像练习生#',
#  '#张艺兴黄金瞳#',
#  '#媒体看中行#',
#  '#我有红唇给我红包#',
#  '#重装突击#',
#  '#临沂房价#',
#  '#尊重也是一种温暖#',
#  '#时空偷渡少女#',
#  '#绿地黄浦滨江豪宅甲醛超标#',
#  '#最美国风花旦#',
#  '#宝宝的少女心#',
#  '#庄粉需知#',
#  '#万达乐园欢乐无限#',
#  '#搜狐新闻资讯版#',
#  '#民生峰享信用卡#',
#  '#王源大主宰#',
#  '#电视剧大主宰#',
#  '#王源#',
#  '#餐饮年会发豪车#',
#  '#王俊凯#',
#  '#贵州看看#',
#  '#贵州突发#',
#  '#小狐狸偷鱼#',
#  '#寻梦环游记#',
#  '#吐槽大会#',
#  '#南宁业之峰装饰#',
#  '#家居创意#',
#  '#公安厅大院#',
#  '#交警红绿灯#',
#  '#冬季大雾天气交通安全提示#',
#  '#新南京唐僧肉#',
#  '#微博股票#',
#  '#财经视频#',
#  '#微博财经#',
#  '#西宁招聘#',
#  '#请丝芭公司公平对待莫寒#',
#  '#爱奇艺体育澳网奇妙之旅#',
#  '#大连生活#',
#  '#王俊凯#',
#  '#寒门博士之死#',
#  '#警民连心#',
#  '#瓜子二手车疑似资金链断裂#',
#  '#春节#',
#  '#外汇黄金分析师#',
#  '#汇添富基金携手城市之光#',
#  '#整点路况#',
#  '#马蓉#',
#  '#宋喆#',
#  '##鹿晗#',
#  '#秒拍#',
#  '#武汉同城#',
#  '#武汉楼市#',
#  '#说到街舞就能想到易烊千玺#',
#  '#百日平安会战#',
#  '#早票网票据交易#',
#  '#西宁房产信息#',
#  '#安亭瑞仕锦庭#',
#  '#盛誉世家#',
#  '#欣悦华庭#',
#  '#上海长滩#',
#  '#瑞和上海印象#',
#  '#尚景丽园#',
#  '#宝龙世家#',
#  '#秋月朗庭尚东区#',
#  '#大学里#',
#  '#万业紫辰苑#',
#  '#碧云壹零#',
#  '#佳兆业君汇上品#',
#  '#天健翠西#',
#  '#远洋万和四季#',
#  '#智富中环尚城#',
#  '#新城盛世#',
#  '#保利艾庐#',
#  '#绿地海域苏河源#',
#  '#西祠热帖#',
#  '#鹿晗#',
#  '#鹿晗热血街舞团#',
#  '#恋与制作人#',
#  '#恋与制作人白起#',
#  '#中班畅想日#',
#  '#记住乡愁#',
#  '#最火女团#',
#  '#洛阳城事#',
#  '#重庆租房#',
#  '#剁手党的避风港#',
#  '#杨幂#',
#  '#肇事逃逸#',
#  '##佛山南海万达广场#',
#  '#中国银行#',
#  '#中国银行客服#',
#  '#柳州万达福克斯健身#',
#  '#宋小宝靠脸吃饭#',
#  '#爱西宁信息台#',
#  '#瓜子二手车疑似资金链断裂#',
#  '#我是一个萌萌兔#',
#  '#陈伟霆#',
#  '#奇奇成长记#',
#  '#那年今日#',
#  '#潜行狙击#',
#  '#东莞婚庆#',
#  '#东莞康帝酒店婚礼#',
#  '#东莞会展酒店婚礼#',
#  '#东莞万达文华酒店婚礼#',
#  '#东莞婚礼策划#',
#  '#东莞定制婚礼#',
#  '#爱抽奖的工行#',
#  '#露露脸晒幸福#',
#  '#银行#',
#  '#秒拍#',
#  '#武汉美食#',
#  '#味道笔记#',
#  '#豚首巴迪与美丽邂逅#',
#  '#汇添富基金携手城市之光#',
#  '#财经视频#',
#  '#深圳交警铁骑#',
#  '#全球跨年#',
#  '#面馆新闻#',
#  '#我有红唇给我红包#',
#  '#四川高速路况#',
#  '#广元路况#',
#  '#交警在路上#',
#  '#忠诚保平安#',
#  '#汽车有态度#',
#  '#温暖身边的人#',
#  '#实时路况#',
#  '#尊重也是一种温暖#',
#  '#株洲城事#',
#  '#我有红唇给我红包#',
#  '#微信#',
#  '#支付宝#',
#  '#财经头条#',
#  '#新浪股吧#',
#  '#财经头条文章#',
#  '#今日看盘#',
#  '#微博股票长文#',
#  '#淘宝优惠劵#',
#  '#三室一厅三拨骗子#',
#  '#双旦畅游南昌万达乐园#',
#  '#午盘聚焦#',
#  '#双旦畅游南昌万达乐园#',
#  '#我有红唇给我红包#',
#  '#平安证券#',
#  '#平安守护#',
#  '#宋小宝靠脸吃饭#',
#  '#银行#',
#  '#营业执照#',
#  '#自助服务#',
#  '#消息#',
#  '#吐槽一波共享单车#',
#  '#王俊凯斯沃琪全球代言#',
#  '#王俊凯#',
#  '#工作动态#',
#  '#清新空气我们在行动#',
#  '#王俊凯#',
#  '#玩视频上火山#',
#  '#平安守护#',
#  '#轻松一刻#',
#  '#我在成都你在哪#',
#  '#交通安全预警提示#',
#  '#贾跃亭#',
#  '#歌手华晨宇#',
#  '#每日一善#',
#  '#平安守护#',
#  '#许嵩青年晚报演唱会#',
#  '#交警红绿灯#',
#  '#瓜子二手车疑似资金链断裂#',
#  '#海口全职#',
#  '#财务招聘#',
#  '#财经#',
#  '#赤峰民生#',
#  '#秦人说事#',
#  '#下雪啦#',
#  '#美出了界#',
#  '#运动不放假#',
#  '#和工行一起云跨年#',
#  '#腾讯新闻#',
#  '#高新那些事儿#',
#  '#海口马拉松#',
#  '#河南高速路况#',
#  '#六安#',
#  '#瓜子二手车疑似资金链断裂#',
#  '#瓜子二手车疑似资金链断裂#',
#  '#摄影#',
#  '#税收实务#',
#  '#财经#',
#  '#露露脸晒幸福#',
#  '#锡城实时路况#',
#  '#临时延长公告#',
#  '#微博之夜#',
#  '#全民比心#',
#  '#张艺兴#',
#  '#张艺兴代言浦发信用卡#',
#  '#张艺兴梦想起飞#',
#  '#张艺兴湖南卫视跨年#',
#  '#张艺兴偶像练习生#',
#  '#张艺兴黄金瞳#',
#  '#平安守护#',
#  '#理财行家#',
#  '#安亭瑞仕锦庭#',
#  '#盛誉世家#',
#  '#欣悦华庭#',
#  '#上海长滩#',
#  '#瑞和上海印象#',
#  '#尚景丽园#',
#  '#宝龙世家#',
#  '#秋月朗庭尚东区#',
#  '#大学里#',
#  '#万业紫辰苑#',
#  '#碧云壹零#',
#  '#佳兆业君汇上品#',
#  '#天健翠西#',
#  '#远洋万和四季#',
#  '#智富中环尚城#',
#  '#新城盛世#',
#  '#保利艾庐#',
#  '#绿地海域苏河源#',
#  '#大盘分析#',
#  '#微博股票#',
#  '#合肥日式美甲美睫#',
#  '#合肥美甲美睫#',
#  '#松风睫毛#',
#  '#会写诗词才是古典女神#',
#  '#合肥日式美甲美睫#',
#  '#合肥美甲#',
#  '#王俊凯#',
#  '#王俊凯解忧杂货店#',
#  '#法庭提醒#',
#  '#我有红唇给我红包#',
#  '#汽车知识#',
#  '#篮球#',
#  '#足彩大推荐#',
#  '#城管动态#',
#  '#我有红唇给我红包#',
#  '#瓜子二手车疑似资金链断裂#',
#  '#最新资讯#',
#  '#媒体看中行#',
#  '#赵又廷#',
#  '#上海美食#',
#  '#舌尖上的中国#',
#  '#上海美食搜罗#',
#  '#上海美食头条#',
#  '#我有红唇给我红包#',
#  '#交通提示#',
#  '#王俊凯掌阅阅读的力量#',
#  '#王俊凯天坑鹰猎#',
#  '#轻氧轻燕燕窝股东创始人维唯#',
#  '#别人家的豪车#',
#  '#平安守护#',
#  '#凯源#',
#  '#西安#',
#  '#北京求助#',
#  '#租房资讯#',
#  '#漳州微博房产#',
#  '#我在成都你在哪#',
#  '#实时路况#',
#  '#通辽万达广场#',
#  '#鹿晗#',
#  '#奇趣汽车#',
#  '#安哥普法#',
#  '#头条文章#',
#  '#新浪看点#',
#  '#柳州身边的事#',
#  '#亚洲新歌榜#',
#  '#长沙下雪#',
#  '#老司机聊车#',
#  '#牛股推荐#',
#  '#财经头条文章#',
#  '#股票分析#',
#  '#今日看盘#',
#  '#琅琊榜之风起长林#',
#  '#支付宝年度账单#',
#  '#王俊凯#',
#  '#湛江市二手车#',
#  '#我就比较厉害了#',
#  '#微博股票#',
#  '#财经视频#',
#  '#微博财经#',
#  '#江西银行考试#',
#  '#宁波招聘#',
#  '#求职季#',
#  '#列宁评车#',
#  '#守护平安#',
#  '#周口生活#',
#  '#王俊凯#',
#  '#遵义新闻#',
#  '#下雪啦#',
#  '#成都空气污染#',
#  '#二代妖精#',
#  '#青秀赶圩#',
#  '#豚首巴迪与美丽邂逅#',
#  '#实习资讯#',
#  '#券商板块#',
#  '#打飞机去买车#',
#  '#法治动态#',
#  '#多五分钟的等待#',
#  '#李易峰#',
#  '#王源遇见你真好#',
#  '#王源#',
#  '#电影遇见你真好#',
#  '#济南租房#',
#  '#济南高新区租房#',
#  '#延安同城#',
#  '#百威啤酒#',
#  '#温暖身边的人#',
#  '#葡萄酒#',
#  '#宋小宝靠脸吃饭#',
#  '#瓜子二手车疑似资金链断裂#',
#  '#我就比较厉害了#',
#  '##你好旧时光#',
#  '#产后恢复#',
#  '#产后护理#',
#  '#周德堂产后恢复#',
#  '#石景山万达广场#',
#  '##万达广场#',
#  '#元旦狂欢#',
#  '#咖啡沙龙#',
#  '#咖啡#',
#  '#时尚#',
#  '#英语词汇#',
#  '#英语单词#',
#  '#微博股票#',
#  '#投资达人说#',
#  '#北部湾经济#',
#  '#合作协议#',
#  '#车事侦查站#',
#  '#财经#',
#  '#龙头股票#',
#  '#孙红雷被代言坑#',
#  '#平昌冬奥会#',
#  '#微博看市#',
#  '#周一股市#',
#  '#转发赢折叠车#',
#  '#一线微观#',
#  '#蜀黍说安全#',
#  '#巨鳄简史#',
#  '#平安守护#',
#  '#理财日课#',
#  '#奇趣汽车#',
#  '#唐嫣#',
#  '#唐嫣时间都知道#',
#  '#我有红唇给我红包#',
#  '#我有红唇给我红包#',
#  '#我在成都你在哪#',
#  '#微博会员福利#',
#  '#龙日一第二季#',
#  '#与进食障碍说分手#',
#  '#我要戒掉暴食症#',
#  '#一路平安#',
#  '#我有红唇给我红包#',
#  '#吴亦凡#',
#  '#微博股票#',
#  '#财经视频#',
#  '#微博财经#',
#  '#停车打卡#',
#  '#湖北卫视爱人同志#',
#  '#财经#',
#  '#炒股干货#',
#  '#头条资讯#',
#  '#支付动态#',
#  '#本溪新鲜事#',
#  '#下雪啦#',
#  '#这一刻的小时光#',
#  '#让红包飞#',
#  '#恒大高薪任命文件#',
#  '#平安证券#',
#  '#每日新闻发布#',
#  '#壶口瀑布#',
#  '#我有红唇给我红包#',
#  '#呷哺呷哺#',
#  '#天津生活#',
#  '#今日看盘#',
#  '#股票#',
#  '#晚高峰路况#',
#  '#协会活动#',
#  '#许嵩#',
#  '#王俊凯#',
#  '#中央纪检委开通举报网站#',
#  '#胡可踢馆火锅店#',
#  '#交警蜀黍来提醒#',
#  '#云南高速路况#',
#  '#一路平安#',
#  '#岳阳求助#',
#  '#靳东恋爱先生#',
#  '#恋爱先生#',
#  '#庄警提示#',
#  '#魔都下雪了吗#',
#  '#中央纪检委开通举报网站#',
#  '#今日看盘#',
#  '#投资达人说#',
#  '#和工行一起云跨年#',
#  '#刘亦菲天使纪元#',
#  '#刘亦菲二代妖精#',
#  '#刘亦菲天梭全球代言人#',
#  '#平安生活论#',
#  '#王俊凯#',
#  '#石家庄租房#',
#  '##李易峰#',
#  '#林心如#',
#  '#周杰#',
#  '#微博汽车微评#',
#  '#天堂里没有车来车往#',
#  '#冀青资讯#',
#  '#合肥新闻#',
#  '#粉丝服务平台#',
#  '#一线微观#',
#  '#我有红唇给我红包#',
#  '#晚高峰路况#',
#  '#冷冷冷#',
#  '#戴佩妮#',
#  '#万达乐园抖音之夜#',
#  '#微博时评团#',
#  '#投资达人说#',
#  '#瓜子二手车疑似资金链断裂#',
#  '#网民正在问#',
#  '#易烊千玺#',
#  '#赤峰新鲜事#',
#  '#封杀封口#',
#  '#一霸手#',
#  '#一线执法有您亲人#',
#  '#法定程序#',
#  '#为官不为#',
#  '#职务行为#',
#  '#法定职责#',
#  '##打黑除恶#',
#  '#公诉#',
#  '#开中巴车撞杀执法检查人撞了白撞#',
#  '#打虎拍蝇#',
#  '#行政违法不作为#',
#  '#公事公不管#',
#  '#第一届新时代资本论坛#',
#  '#南宁本地新闻#',
#  '#突发#',
#  '#交通宣传栏#',
#  '#润华雷克萨斯济宁高新区店#',
#  '#有观点的财经社区#',
#  '#平安证券#',
#  '#最美表演#',
#  '#李宇春#',
#  '#郜林#',
#  '#国足#',
#  '#足球新鲜事#',
#  '#新娘跟妆#',
#  '#新娘化妆#',
#  '#郑州万达重工股份有限公司#',
#  '#王鸥#',
#  '#王鸥推手#',
#  '#太平聚焦#',
#  '#网易新闻#',
#  '#罗蟹#',
#  '#罗喉#',
#  '#元邪皇#',
#  '#转发赢折叠车#',
#  '#王俊凯#',
#  '#汽车#',
#  '#午盘聚焦#',
#  '#王俊凯#',
#  '#我在成都你在哪#',
#  '#瓜子二手车疑似资金链断裂#',
#  '#广铁出行微提示#',
#  '#早票网票据贴现#',
#  '#花式比心#',
#  '#个股推荐与走势分析#',
#  '#今日腊八节#',
#  '#绥化万达广场#',
#  '#平安守护#',
#  '#余票信息#',
#  '#北京冬奥牵手联通#',
#  '#冬奥一起来#',
#  '#大宗交易#',
#  '#平安证券#',
#  '#晨报新闻早餐#',
#  '#贵州银行招聘#',
#  '#淀粉探店#',
#  '#万达美食地图#',
#  '#我在成都你在哪#',
#  '#财经视频#',
#  '#淀粉探店#',
#  '#天籁之战#',
#  '##快乐冰雪季#',
#  '#小米专卖店的日常#',
#  '#直播济南#',
#  '#明月公益相亲#',
#  '#景向谁依#',
#  '#景萌萌的日常#',
#  '#我有红唇给我红包#',
#  '#文在寅访华之行#',
#  '#住在成都#',
#  '#雪天出行二桥路况#',
#  '#牛人点金#',
#  '#延安生活#',
#  '#明月公益相亲#',
#  '#不负好时光#',
#  '#新年新套路#',
#  '#网剧器灵#',
#  '#日本汇率#',
#  '#今日看盘#',
#  '#一线微观#',
#  '#孙红雷被代言坑#',
#  '#最新交通信息#',
#  '#汽车#',
#  '#小西观察#',
#  '#来自成都的新派川菜终于来福州啦#',
#  '#今日腊八节#',
#  '#王俊凯#',
#  '#王俊凯#',
#  '#最新中国城市排名#',
#  '#宁波美食种草机#',
#  '##市场研判#',
#  '#摄影#',
#  '#萌娃#',
#  '#楼市头条#',
#  '#福冈印象#',
#  '#秒拍#',
#  '#平安守护#',
#  '#秦岭二月的访谈#',
#  '#段造英雄#',
#  '#钱塘江论坛#',
#  '#今日看盘#',
#  '#今日看盘#',
#  '#平安守护#',
#  '#运动教室#',
#  '#中国工商银行股份有限公司牡丹卡中心#',
#  '#易烊千玺这就是街舞#',
#  '#安庆消防温馨提示#',
#  '#沈阳音乐学院#',
#  '#汽车评中评#',
#  '#平安证券#',
#  '#真人版跳一跳#',
#  '#微博股票#',
#  '#财经视频#',
#  '#微博财经#',
#  '#杭州生活#',
#  '#尊重也是一种温暖#',
#  '#论坛精选日报#',
#  '#汇市黄金日评#',
#  '#晚安#',
#  '#购车帮帮忙#',
#  '#活动#',
#  '#王源漫游挪威#',
#  '#冰雪大使王源挪威行#',
#  '#王源#',
#  '#王俊凯#',
#  '#中国工商银行股份有限公司牡丹卡中心#',
#  '#最火女团#',
#  '#毕节同城看世界#',
#  '#吐槽#',
#  '#秒拍#',
#  '#财经#',
#  '#畅游北京#',
#  '#遇见北京#',
#  '#车友互助#',
#  '#冒个泡#',
#  '#尊重也是一种温暖#',
#  '#平安证券#',
#  '#一路平安#',
#  '#杞人忧天进入疲劳期#',
#  '#便民服务#',
#  '#头条文章#',
#  '#新浪看点#',
#  '#孙红雷被代言坑#',
#  '#见后任务#',
#  '#第一投教#',
#  '#中超联赛#',
#  '#图文战#',
#  '#杭州免中介租房#',
#  '#杭州租房#',
#  '#牛股发现#',
#  '#超短线牛股#',
#  '#奇点敲股#',
#  '#南昌万达乐园抖音跨年夜#',
#  '#晚安#',
#  '#三里屯#',
#  '#汽车之家论坛#',
#  '#秒拍#',
#  '#济南#',
#  '#明星保姆车#',
#  '#奔驰房车#',
#  '#秒拍娱乐快报#',
#  '#咸阳万达#',
#  '#社会实践#',
#  '#百日会战#',
#  '#明日头条征文#',
#  '#尊重也是一种温暖#',
#  '#民生服务#',
#  '#万科玖里#',
#  '#黄晓明给徐娇拔草#',
#  '#合肥万达乐园跨年夜#',
#  '#平安守护#',
#  '#外地人在北京#',
#  '#歌手华晨宇#',
#  '#华晨宇#',
#  '#今日看盘#',
#  '#范冰冰同款面膜#',
#  '#葫芦岛生活#',
#  '#猫咪咖啡馆#',
#  '#豚首巴迪与美丽邂逅#',
#  '#江西国企考试#',
#  '#中超联赛#',
#  '#我有红唇给我红包#',
#  '#早票网票据贴现#',
#  '#吉利汽车#',
#  '#长城汽车#',
#  '#秒拍#',
#  '#财经#',
#  '#唐山美食#',
#  '#心机老公陆瑾年#',
#  '#孙红雷被代言坑#',
#  '#温哥华二手车#',
#  '#豚首巴迪与美丽邂逅#',
#  '#陈靖川#',
#  '#高速路况#',
#  '#烤匠豆花烤鱼#',
#  '#一洋刺身#',
#  '#平安守护#',
#  '#寒门博士之死#',
#  '#林峯#',
#  '#万达乐园抖音之夜#',
#  '#实习情报速递#',
#  '#北京实习#',
#  '#九州缥缈录#',
#  '#骑焕红包年#',
#  '#乐玩成都#',
#  '#狗爸说车#',
#  '#狗爸日记#',
#  '#系猫猫走走吃吃喝喝#',
#  '#王俊凯#',
#  '#奏耐同城#',
#  '#武艺#',
#  '#财经#',
#  '#偶像练习生#',
#  '#最火女团#',
#  '#济南美食#',
#  '#经纬三分钟#',
#  '#征婚交友#',
#  '#四川高速路况#',
#  '#我有红唇给我红包#',
#  '#瓜子二手车疑似资金链断裂#',
#  '#沃尔沃与奥迪相撞#',
#  '#十三水棋牌游戏#',
#  '#小米晚安#',
#  '#财经头条文章#',
#  '#股票分析#',
#  '#瓜子二手车疑似资金链断裂#',
#  '#汽车视频#',
#  '#瓜子二手车疑似资金链断裂#',
#  '#东成西享#',
#  '#内江教师公招#',
#  '#搜狐新闻资讯版#',
#  '#绿地控股#',
#  '#北新建材#',
#  '#欧菲科技#',
#  '#新浪股吧#',
#  '#股市雷达#',
#  '#微博股票#',
#  '#重庆求租#',
#  '#高国新#',
#  '#艺术#',
#  '#王俊凯代言掌阅#',
#  '#阅读的力量#',
#  '#今日看盘#',
#  '#快乐大本营#',
#  '#小车隧道撞上大巴#',
#  '#王俊凯#',
#  '#国民老公#',
#  '#韩庚#',
#  '#会计理论#',
#  '#出纳实务#',
#  '#会计实务#',
#  '#会计法#',
#  '#汽车#',
#  '#车圈话题#',
#  '#新车情报局#',
#  '#网易新闻#',
#  '#身边的小米之家#',
#  '#冻死宝宝了#',
#  '#抗雪防冻#',
#  '#新闻安庆#',
#  '#新闻#',
#  '#搞笑幽默#',
#  '#兴业动态#',
#  '#和工行一起云跨年#',
#  '#深圳交警一线#',
#  '#私服街拍#',
#  '#天猫旗舰店#',
#  '#优惠券分享联盟#',
#  '#利客优惠#',
#  '#双十一爆款清单#',
#  '#战斗民族#',
#  '#普京大帝#',
#  '#今日看盘#',
#  '#微博股票#',
#  '#平安证券#',
#  '#名师带你炒股#',
#  '#王俊凯#',
#  '#绿地控股#',
#  '#欧菲科技#',
#  '#新浪股吧#',
#  '#乐视#',
#  '#政策法规#',
#  '#王俊凯解忧杂货店#',
#  '#王俊凯#',
#  '#新品小米电视#',
#  '#巴中这点事#',
#  '#油价上调#',
#  '#红旗品牌#',
#  '#秒拍#',
#  '#中国足球小将#',
#  '#萌宝#',
#  '#武汉新生儿摄影#',
#  '#武汉儿童摄影#',
#  '#绿地控股#',
#  '#股市雷达#',
#  '#微博股票#',
#  '#许嵩#',
#  '#我的这颗少女心#',
#  '#潜行狙击#',
#  '#瓜子二手车疑似资金链断裂#',
#  '#尊重也是一种温暖#',
#  '#东部崛起看长沙县#',
#  '#亚洲新歌榜#',
#  '#轻松一刻#',
#  '#国民老公电视剧#',
#  '#社区广角#',
#  '##中国有嘻哈#',
#  '#我有红唇给我红包#',
#  '#秦人说事#',
#  '#今日贴纸打卡#',
#  '#张艺兴#',
#  '#张艺兴代言浦发信用卡#',
#  '#张艺兴梦想起飞#',
#  '#张艺兴湖南卫视跨年#',
#  '#张艺兴偶像练习生#',
#  '#张艺兴黄金瞳#',
#  '#鹿晗小黄车#',
#  '#餐饮年会发豪车#',
#  '#喀纳斯#',
#  '#许嵩#',
#  '#今日看盘#',
#  '#微博股票#',
#  '#淮南生活#',
#  '#随手拍淮南#',
#  '#微博时评团#',
#  '#投资达人说#',
#  '#深圳坪山交警#',
#  '#纪录片创新中国#',
#  '#汽车#',
#  '#美好生活无押力#',
#  '#最火女团#',
#  '#小健聊车#',
#  '#秒拍#',
#  '#实时路况#',
#  '#农行微动态#',
#  '#品快讯#',
#  '#渔资鱼味#',
#  '#平安守护#',
#  '#小王警官报路况#',
#  '#短线牛股汇集#',
#  '#股评师问答#',
#  '#中信证券#',
#  '#中国工商银行股份有限公司牡丹卡中心#',
#  '#李小璐#',
#  '#许嵩青年晚报演唱会#',
#  '#百威啤酒#',
#  '#汇添富基金携手城市之光#',
#  '#心理罪之城市之光#',
#  '#平安守护#',
#  '#运动教室#',
#  '#漫画#',
#  '#漫画推荐#',
#  '#杀戮跟踪#',
#  '#爱慕的少年#',
#  '#在那尽头#',
#  '#寂静鸟#',
#  '#央视新闻微直播#',
#  '#出行提醒#',
#  '#李楠说道#',
#  '#直播南充#',
#  '#武汉纹身#',
#  '#武汉超仔纹身馆作品#',
#  '#现场设计纹身#',
#  '#超仔张子作品#',
#  '#私人订制纹身#',
#  '#江汉路纹身#',
#  '#汉口江汉路万达电影院电梯旁#',
#  '#微博股票#',
#  '#财经视频#',
#  '#微博财经#',
#  '#压型钢板#',
#  '#说说楼承板#',
#  '#许嵩#',
#  '#平安证券#',
#  '#我的家乡在泉州#',
#  '#新浪头条#',
#  '#股票技术分享#',
#  '#股票#',
#  '#新浪股吧#',
#  '#盘面点睛#',
#  '#今日看盘#',
#  '#万州城事#',
#  '#大盘分析#',
#  '#林峯#',
#  '#平安守护#',
#  '#银川餐厅推荐#',
#  '#陈伟霆#',
#  '#陈伟霆汉堡#',
#  '#太原年货节#',
#  '#惠民团车节#',
#  '#平安证券#',
#  '#餐饮年会发豪车#',
#  '#农行微民生#',
#  '#秒拍#',
#  '#推文#',
#  '#李小璐#',
#  '#平安守护#',
#  '#我有红唇给我红包#',
#  '#马蓉#',
#  '#宋喆#',
#  '#财经#',
#  '#尊重也是一种温暖#',
#  '#悉尼#',
#  '#美出了界#',
#  '#秋色宜人#',
#  '#琅琊榜之风起长林#',
#  '#许嵩青年晚报演唱会#',
#  '#温暖身边的人#',
#  '#小万说电影#',
#  '##微商#',
#  '#宝妈#',
#  '#惠来#',
#  '##希芸#',
#  '#希芸招各级代理#',
#  '#无问西东#',
#  '#快乐冰雪季#',
#  '#工资去哪儿了#',
#  '#京视频#',
#  '#农行快讯#',
#  '#政策法规#',
#  '#银行教会我的事#',
#  '#女主人出嫁爱狗狂追婚车#',
#  '#记住乡愁#',
#  '#宁波租房在线#',
#  '#消防提示#',
#  '#张继科梦初始的地方#',
#  '#头条文章#',
#  '#微博股票热议榜#',
#  '#微博股票#',
#  '#阅读的力量#',
#  '#电视剧天坑鹰猎#',
#  '#王俊凯#',
#  '#媒体看中行#',
#  '#宋小宝靠脸吃饭#',
#  '#世界和我都爱你#',
#  '#平安守护#',
#  '#广州证券#',
#  '#和工行一起云跨年#',
#  '##你好旧时光#',
#  '#我有红唇给我红包#',
#  '#平安守护#',
#  '#林峯#',
#  '#情感#',
#  '#贝贝柏闻奇葩舞#',
#  '#王源遇见你真好#',
#  '#王源#',
#  '#电影遇见你真好#',
#  '#林峯#',
#  '#深圳事儿#',
#  '#我在成都你在哪#',
#  '#中国工商银行股份有限公司牡丹卡中心#',
#  '#我在成都你在哪#',
#  '#内蒙古贷款#',
#  '#海口新鲜事#',
#  '#一图读懂春节档#',
#  '#股票#',
#  '#优惠白菜菌#',
#  '#瓜子二手车疑似资金链断裂#',
#  '#我有红唇给我红包#',
#  '#实时路况#',
#  '#亮辰说事#',
#  '#王俊凯#',
#  '#小米感恩季#',
#  '#财经#',
#  '#汽车#',
#  '#张钧甯#',
#  '#马蓉#',
#  '#宋喆#',
#  '#阴阳师手游歧视内地玩家#',
#  '#新浪财经#',
#  '#头条文章#',
#  '#微博头条#',
#  '#微博股票#',
#  '#新浪看点#',
#  '#新浪股吧#',
#  '#财经#',
#  '##护肤#',
#  '#微商#',
#  '#宝妈#',
#  '#惠来#',
#  '##希芸#',
#  '#希芸招各级代理#',
#  '#消防提示#',
#  '#阜阳新闻#',
#  '#大盘直击#',
#  '#股市点评#',
#  '#瓜子二手车疑似资金链断裂#',
#  '#沫沫信息#',
#  '#电影红海行动#',
#  '#纪录片创新中国#',
#  '#投资达人说#',
#  '#股票分析#',
#  '#属于我的金球时刻#',
#  '#广州长隆欢乐世界#',
#  '#烎潮音发布夜#',
#  '#直播济南#',
#  '#明月公益相亲#',
#  '#媒体看中行#',
#  '#足金之星#',
#  '#足金联赛#',
#  '#七元的感恩日记#',
#  '#阜新新闻#',
#  '#水资源税试点#',
#  '#陕北新闻哥吐槽#',
#  '#江淮警事#',
#  '#搜狐新闻资讯版#',
#  '#松柏智慧#',
#  '#胡一天#',
#  '#金融时报年会暨金牌榜颁奖典礼#',
#  '#高德地图#',
#  '#上海毕业生租房#',
#  '#上海租房大家帮#',
#  '#找室友#',
#  '#租房#',
#  '#王俊凯快本解忧跨年#',
#  '#王俊凯解忧杂货店#',
#  '#王俊凯#',
#  '#焕蓝梦想基金#',
#  '#制造业强国#',
#  '#科技#',
#  '#搜狐新闻资讯版#',
#  '#西粉播报#',
#  '#王俊凯#',
#  '#早安平安#',
#  '#股票#',
#  '#股市午评#',
#  '#腾讯新闻#',
#  '#儿童摄影#',
#  '#王俊凯解忧杂货店#',
#  '#餐饮年会发豪车#',
#  '#江若琳被求婚成功#',
#  '#餐饮年会发豪车#',
#  '#王俊凯#',
#  '#年货节#',
#  '#微商#',
#  '#平安守护#',
#  '#我有红唇给我红包#',
#  '#顺丰快递#',
#  '#投资达人说#',
#  '#李宇春#',
#  '#荆门吉诚装饰#',
#  '#平安夜#',
#  '#圣诞节#',
#  '#房产天地#',
#  '#房产#',
#  '#下雪啦#',
#  '##快乐冰雪季#',
#  '#许嵩青年晚报演唱会#',
#  '#华夏银行#',
#  '#华夏银行信用卡中心#',
#  '#乌鲁木齐探店#',
#  '#尊重也是一种温暖#',
#  '#孙红雷被代言坑#',
#  '#及时调整预付金额度#',
#  '#我有红唇给我红包#',
#  '#腊八喝碗腊八粥#',
#  '#西安装修#',
#  '#王俊凯#',
#  '#咸阳高速路况播报#',
#  '#板块机会#',
#  '#周一股市#',
#  ...]

# %%
df_content_str = df_content.apply(lambda row: filterStr(row), axis = 1)

# %% [markdown]
# ## 分句

# %% [markdown]
# ## 左右熵
